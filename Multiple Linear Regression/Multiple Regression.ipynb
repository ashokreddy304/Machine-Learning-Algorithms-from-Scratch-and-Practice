# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
df = pd.read_csv('Investment.csv')

# %%
df.head()
# Out:
#    DigitalMarketing  Promotion   Research      State     Profit
# 0         165349.20  136897.80  471784.10  Hyderabad  192261.83
# 1         162597.70  151377.59  443898.53  Bangalore  191792.06
# 2         153441.51  101145.55  407934.54    Chennai  191050.39
# 3         144372.41  118671.85  383199.62  Hyderabad  182901.99
# 4         142107.34   91391.77  366168.42    Chennai  166187.94

# %%
X = df.drop(columns=['Profit'])
y = df['Profit']

# %%
X = pd.get_dummies(X,dtype=int)

# %%
X.head()
# Out:
#    DigitalMarketing  Promotion   Research  State_Bangalore  State_Chennai  \
# 0         165349.20  136897.80  471784.10                0              0
# 1         162597.70  151377.59  443898.53                1              0
# 2         153441.51  101145.55  407934.54                0              1
# 3         144372.41  118671.85  383199.62                0              0
# 4         142107.34   91391.77  366168.42                0              1
#
#    State_Hyderabad
# 0                1
# 1                0
# 2                0
# 3                1
# 4                0

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,y_train.shape
# Out:
# ((40, 6), (40,))

# %%
X_test.shape,y_test.shape
# Out:
# ((10, 6), (10,))

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([103015.20159796, 132582.27760816, 132447.73845174,  71976.09851258,
#        178537.48221055, 116161.24230165,  67851.69209676,  98791.73374687,
#        113969.43533012, 167921.0656955 ])

# %%
m = regressor.coef_
m
# Out:
# array([ 7.73467193e-01,  3.28845975e-02,  3.66100259e-02,  8.66383692e+01,
#        -8.72645791e+02,  7.86007422e+02])

# %%
c = regressor.intercept_
c
# Out:
# np.float64(42467.52924855311)

# %%
c = regressor.intercept_

X = np.append(arr = np.full((50,1),c).astype(int),values=X,axis=1)

# %%
X
# Out:
# array([[4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.2333488e+05,
#         1.0867917e+05, 3.0498162e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.0191308e+05,
#         1.1059411e+05, 2.2916095e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.0067196e+05,
#         9.1790610e+04, 2.4974455e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 9.3863750e+04,
#         1.2732038e+05, 2.4983944e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 9.1992390e+04,
#         1.3549507e+05, 2.5266493e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.1994324e+05,
#         1.5654742e+05, 2.5651292e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.1452361e+05,
#         1.2261684e+05, 2.6177623e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.8013110e+04,
#         1.2159755e+05, 2.6434606e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 9.4657160e+04,
#         1.4507758e+05, 2.8257431e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 9.1749160e+04,
#         1.1417579e+05, 2.9491957e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 8.6419700e+04,
#         1.5351411e+05, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.6253860e+04,
#         1.1386730e+05, 2.9866447e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.8389470e+04,
#         1.5377343e+05, 2.9973729e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.3994560e+04,
#         1.2278275e+05, 3.0331926e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.7532530e+04,
#         1.0575103e+05, 3.0476873e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.7044010e+04,
#         9.9281340e+04, 1.4057481e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.4664710e+04,
#         1.3955316e+05, 1.3796262e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.5328870e+04,
#         1.4413598e+05, 1.3405007e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 7.2107600e+04,
#         1.2786455e+05, 3.5318381e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.6051520e+04,
#         1.8264556e+05, 1.1814820e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.5605480e+04,
#         1.5303206e+05, 1.0713838e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.1994480e+04,
#         1.1564128e+05, 9.1131240e+04, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.1136380e+04,
#         1.5270192e+05, 8.8218230e+04, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 6.3408860e+04,
#         1.2921961e+05, 4.6085250e+04, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 5.5493950e+04,
#         1.0305749e+05, 2.1463481e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 4.6426070e+04,
#         1.5769392e+05, 2.1079767e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 4.6014020e+04,
#         8.5047440e+04, 2.0551764e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.8663760e+04,
#         1.2705621e+05, 2.0112682e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 4.4069950e+04,
#         5.1283140e+04, 1.9702942e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.0229590e+04,
#         6.5947930e+04, 1.8526510e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 3.8558510e+04,
#         8.2982090e+04, 1.7499930e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.8754330e+04,
#         1.1854605e+05, 1.7279567e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.7892920e+04,
#         8.4710770e+04, 1.6447071e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.3640930e+04,
#         9.6189630e+04, 1.4800111e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.5505730e+04,
#         1.2738230e+05, 3.5534170e+04, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 2.2177740e+04,
#         1.5480614e+05, 2.8334720e+04, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.0002300e+03,
#         1.2415304e+05, 1.9039300e+03, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 1.3154600e+03,
#         1.1581621e+05, 2.9711446e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 0.0000000e+00,
#         1.3542692e+05, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 5.4205000e+02,
#         5.1743150e+04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [4.2467000e+04, 4.2467000e+04, 4.2467000e+04, 0.0000000e+00,
#         1.1698380e+05, 4.5173060e+04, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00]])

# %%
X_opt = X[:,[0,1,2,3,4,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Wed, 24 Sep 2025   Prob (F-statistic):           8.51e-29
# Time:                        19:52:16   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5906      0.080      7.377      0.000       0.429       0.752
# x1             0.5906      0.080      7.377      0.000       0.429       0.752
# x2             0.8057      0.046     17.646      0.000       0.714       0.898
# x3            -0.0268      0.052     -0.520      0.606      -0.131       0.077
# x4             0.0272      0.017      1.627      0.111      -0.006       0.061
# x5           -70.2265   2828.752     -0.025      0.980   -5767.625    5627.172
# ==============================================================================
# Omnibus:                       14.785   Durbin-Watson:                   1.281
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.242
# Skew:                          -0.949   Prob(JB):                     2.44e-05
# Kurtosis:                       5.568   Cond. No.                     2.68e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.59e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:,[0,1,2,3,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     278.7
# Date:                Wed, 24 Sep 2025   Prob (F-statistic):           1.68e-29
# Time:                        19:57:13   Log-Likelihood:                -526.82
# No. Observations:                  50   AIC:                             1062.
# Df Residuals:                      46   BIC:                             1069.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6487      0.073      8.896      0.000       0.502       0.795
# x1             0.6487      0.073      8.896      0.000       0.502       0.795
# x2             0.8613      0.031     27.974      0.000       0.799       0.923
# x3            -0.0528      0.050     -1.058      0.296      -0.153       0.048
# x4          -502.8903   2866.249     -0.175      0.861   -6272.350    5266.570
# ==============================================================================
# Omnibus:                       14.294   Durbin-Watson:                   1.184
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.252
# Skew:                          -0.956   Prob(JB):                     6.60e-05
# Kurtosis:                       5.364   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.08e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:,[0,1,2,3]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     426.8
# Date:                Wed, 24 Sep 2025   Prob (F-statistic):           7.29e-31
# Time:                        19:57:43   Log-Likelihood:                -526.83
# No. Observations:                  50   AIC:                             1060.
# Df Residuals:                      47   BIC:                             1065.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6462      0.071      9.122      0.000       0.504       0.789
# x1             0.6462      0.071      9.122      0.000       0.504       0.789
# x2             0.8621      0.030     28.589      0.000       0.801       0.923
# x3            -0.0530      0.049     -1.073      0.289      -0.152       0.046
# ==============================================================================
# Omnibus:                       14.678   Durbin-Watson:                   1.189
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.449
# Skew:                          -0.961   Prob(JB):                     3.63e-05
# Kurtosis:                       5.474   Cond. No.                     3.60e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.65e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:,[0,1,3]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Wed, 24 Sep 2025   Prob (F-statistic):              0.162
# Time:                        19:58:00   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9063      0.298      3.040      0.004       0.307       1.506
# x1             0.9063      0.298      3.040      0.004       0.307       1.506
# x2             0.2887      0.203      1.419      0.162      -0.120       0.698
# ==============================================================================
# Omnibus:                        0.126   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.939   Jarque-Bera (JB):                0.110
# Skew:                           0.093   Prob(JB):                        0.947
# Kurtosis:                       2.866   Cond. No.                     1.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.68e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:,[0,1]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 24 Sep 2025   Prob (F-statistic):                nan
# Time:                        19:58:13   Log-Likelihood:                -600.65
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      49   BIC:                             1205.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3188      0.067     19.651      0.000       1.184       1.454
# x1             1.3188      0.067     19.651      0.000       1.184       1.454
# ==============================================================================
# Omnibus:                        0.018   Durbin-Watson:                   0.020
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.068
# Skew:                           0.023   Prob(JB):                        0.966
# Kurtosis:                       2.825   Cond. No.                     1.92e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.89e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
bias = regressor.score(X_train,y_train)
bias
# Out:
# 0.9501847627493607

# %%
variance = regressor.score(X_test,y_test)
variance
# Out:
# 0.9347068473282424
